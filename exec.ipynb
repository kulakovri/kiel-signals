# %%
from src.templates import signalstemp

signalstemp.compare_signals(
    ['2-051-NIST.csv',
     '2-020-NIST610.csv', '2-034-SPH.csv',
         '2-036-VK18-5h-x2-2-41L34a.csv',
         '2-037-VK18-5h-x2-2-41L35.csv',
         '2-038-VK18-5h-x2-2-41L35a.csv'],
    'Na23'
)
# Out:
# /Users/romankulakov/kiel-py/src/objects/signals.py:178: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   skipfooter=1
# /Users/romankulakov/kiel-py/src/objects/signals.py:178: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   skipfooter=1
# /Users/romankulakov/kiel-py/src/objects/signals.py:178: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   skipfooter=1
# /Users/romankulakov/kiel-py/src/objects/signals.py:178: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   skipfooter=1
# ...

# %%
from src.templates import zonebuilder

zonebuilder.compare_grain_with_bse()
# Out:
# /Users/romankulakov/kiel-py/src/objects/signals.py:187: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   skipfooter=1
# {'Li7': 0.0012210247439546496, 'Na23': 0.0007756525082541664, 'Mg24': 0.0009899195933112804, 'Al27': 0.0008810921094621078, 'Si29': 0.021169600391071124, 'P31': 0.0029078167618820493, 'K39': 0.0011164884594736732, 'Ca43': 0.3725765216343089, 'Ca44': 0.023756143138810318, 'Ti47': 0.007078487131534819, 'Mn55': 0.00045884527466298576, 'Fe57': 0.019522678474147202, 'Cu65': 0.0018826570506536814, 'Ga71': 0.0008675904279749774, 'Sr88': 0.0004089163443217229, 'Y89': 0.000344031221255576, 'Ba138': 0.00044645813279568867, 'Ce140': 0.0003448749194162081, 'Pb208': 0.0007297292456009453}
# ...

# %%
from src.templates import signalstemp

signalstemp.build_grain()
# Out:
# /Users/romankulakov/kiel-py/src/objects/signals.py:172: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   skipfooter=1
#            Ca44      Na23      K39       Al27       Si29    An
# 0      61794.71  28482.45  1582.70  111176.94  177155.45  55.0
# 1      78100.83  31090.78  1420.57  119917.86  206328.24  58.0
# 2      76227.50  33799.49  1855.77  127592.78  216384.16  56.0
# 3      75462.69  36305.18  1747.60  136928.95  217350.61  54.0
# 4      88621.86  34765.99  1521.73  127274.73  251015.12  59.0
# ...         ...       ...      ...        ...        ...   ...
# 2138  111977.45  33659.03  1288.61  147417.25  260774.50  65.0
# 2139   95658.81  35951.96  1426.56  160939.58  248867.24  60.0
# 2140   99230.76  36091.31  1434.87  180639.20  279497.84  61.0
# 2141  105154.39  35485.57  1722.68  177898.08  309879.73  62.0
# ...

# %%
from src.templates import zonebuilder

zonebuilder.build_profiles_divided("Ba138")
zonebuilder.build_profiles_divided("Sr88")
zonebuilder.build_profiles_divided("Fe57")
zonebuilder.build_profiles_divided("Ti47")
zonebuilder.build_profiles_divided("Ca44")
# Out:
# /Users/romankulakov/kiel-py/src/objects/signals.py:187: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   skipfooter=1
# /Users/romankulakov/kiel-py/src/objects/signals.py:187: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   skipfooter=1
# /Users/romankulakov/kiel-py/src/objects/signals.py:187: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   skipfooter=1
# /Users/romankulakov/kiel-py/src/objects/signals.py:187: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   skipfooter=1
# ...
