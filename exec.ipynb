# %%
from src.objects import signals

signs = signals.SignalProfile('1-004-SPH.csv')
signs.build_percentage_profile('Mg24')
# Out:
# /Users/romankulakov/kiel-py/src/objects/signals.py:30: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   skipfooter=1

# %%
from src.templates import signalstemp

signalstemp.get_standard_ppm_cps()
# Out:
# /Users/romankulakov/kiel-py/src/objects/signals.py:30: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   skipfooter=1
#                         Li7      Na23      Mg24      Al27      Si29       P31  \
# 1-001-N610.csv     0.001744  0.001122  0.001435  0.001301  0.032499  0.004824
# 1-002-N610.csv     0.001723  0.001125  0.001457  0.001351  0.032990  0.004765
# 1-003-BCR2.csv     0.001655  0.001051  0.001537  0.001210  0.029070  0.000403
# 1-004-SPH.csv      0.003018  0.002089  0.003165  0.002482  0.057586  0.006110
# 1-006-SPH.csv      0.002999  0.002021  0.002955  0.002321  0.054188  0.006817
# 1-016-NIST610.csv  0.001202  0.000749  0.000982  0.000878  0.021616  0.003034
# 1-017-NIST610.csv  0.001229  0.000787  0.001024  0.000920  0.022378  0.003119
# 1-018-SPH4.csv     0.003678  0.002593  0.003667  0.002850  0.065083  0.007093
# ...
