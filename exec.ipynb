# %%
from src.templates import zonebuilder

zonebuilder.build_grain_and_compare_with_bse(['2-034-SPH.csv', '2-047-SPH.csv', '2-048-SPH.csv'])
zonebuilder.build_grain_and_compare_with_bse(['2-050-NIST.csv'])
zonebuilder.build_grain_and_compare_with_bse(['2-051-NIST.csv'])
zonebuilder.build_grain_and_compare_with_bse(['2-034-SPH.csv'])
zonebuilder.build_grain_and_compare_with_bse(['2-033-SPH.csv'])
# Out:
# /Users/romankulakov/kiel-py/src/objects/signals.py:142: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   skipfooter=1
# {'Li7': 0.0025993651656455274, 'Na23': 0.0018224081639890237, 'Mg24': 0.0027054228092005203, 'Al27': 0.002127050011487273, 'Si29': 0.04623989228367992, 'P31': 0.00668548972190611, 'K39': 0.0018369650665090217, 'Ca43': 0.9536143815723367, 'Ca44': 0.06061304198940239, 'Ti47': 0.013779286147328521, 'Mn55': 0.0022844270620506826, 'Fe57': 0.05628710038608387, 'Cu65': 0.004273749561176214, 'Ga71': 0.002187414762676861, 'Sr88': 0.0010771649272076466, 'Y89': 0.000914008263186016, 'Ba138': 0.0011177346098139133, 'Ce140': 0.0008840880955466463, 'Pb208': 0.0017239875060350246}
# ...

# %%
from src.objects import signals

oxide = signals.Oxide("SiO2")
print(oxide.ppm_weight_ratio)
# Out:
# 6370.816642244371
