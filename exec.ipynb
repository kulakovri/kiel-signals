# %%
from src.templates import zonebuilder

zoned_plagioclase = zonebuilder.compare_profile_with_bse()
# Out:
#      Distance core to rim, mkm       An  Dist from rim
# 0                        0.000  52.0634        550.714
# 1                        0.714  53.3580        550.000
# 2                        1.429  53.8065        549.286
# 3                        2.143  53.8402        548.571
# 4                        2.857  52.8505        547.857
# ..                         ...      ...            ...
# 767                    547.857  52.2136          2.857
# 768                    548.571  54.3361          2.143
# 769                    549.286  55.3395          1.429
# 770                    550.000  53.0055          0.714
# 771                    550.714  50.1008          0.000
#
# [772 rows x 3 columns]
#      Distance core to rim, mkm       An  Dist from rim
# 0                        0.000  53.6939        420.000
# 1                        0.714  51.8978        419.286
# 2                        1.429  50.1740        418.571
# 3                        2.143  49.4211        417.857
# ...

# %%
from src.templates import signalstemp

signalstemp.build_grain()
# Out:
# loading signal profile from 2-035-VK18-5h-x2-2-41L34.csv
# 89     666.600000
# 90     666.033165
# 91     665.466330
# 92     664.899212
# 93     664.332378
#           ...
# 686    328.167339
# 687    327.600504
# 688    327.033670
# 689    326.466835
# 690    325.900000
# Name: Dist from rim, Length: 602, dtype: float64
# loading signal profile from 2-036-VK18-5h-x2-2-41L34a.csv
# 96     325.900000
# 97     325.212513
# 98     324.525025
# 99     323.837538
# 100    323.150050
#           ...
# 566      2.750294
# 567      2.062806
# 568      1.375319
# 569      0.687487
# 570      0.000000
# Name: Dist from rim, Length: 475, dtype: float64
# loading signal profile from 2-037-VK18-5h-x2-2-41L35.csv
# 85       0.000000
# 86       0.575428
# 87       1.151144
# 88       1.726572
# 89       2.302000
#           ...
# 754    384.998000
# 755    385.573715
# 756    386.149144
# 757    386.724572
# 758    387.300000
# Name: Dist from rim, Length: 674, dtype: float64
# ...

# %%
string = "2-010-VK18-3a-2-2L21a.csv"
print((string.split("-"))[-1].split("a.csv")[0])
# Out:
# 2L21
